# %% [markdown]
# ## Unit Tests
# The following code is used to test the viability of the custom OpenAI gym environment.

# %%
import unittest
from ipynb.fs.full.PianoHandv1 import *

# %%
class UnitTests(unittest.TestCase):
 
    def test_action0(self):                    # Action 0 = Test if theta 1 of finger 1 increases by 1
        env = PianoHandEnv('C')
        env.reset()
        s0 = env.finger_currangle
        state = s0[0][0]
        s1, r, d, _, _ = env.step(0)
        s2 = env.finger_currangle
        self.assertEqual(s1, s2)
        self.assertEqual(state+1, s1[0][0])
        
    def test_action1(self):                    # Action 1 = Test if theta 1 of finger 1 decreases by 1
        env = PianoHandEnv('C')
        env.reset()
        s0 = env.finger_currangle
        state = s0[0][0]
        s1, r, d, _, _ = env.step(1)
        s2 = env.finger_currangle
        self.assertEqual(s1, s2)
        self.assertEqual(state-1, s1[0][0])
        
    def test_action2(self):                    # Action 2 = Test if theta 2 of finger 1 increases by 1
        env = PianoHandEnv('C')
        env.reset()
        s0 = env.finger_currangle
        state = s0[0][1]
        s1, r, d, _, _ = env.step(2)
        s2 = env.finger_currangle
        self.assertEqual(s1,s2)
        self.assertEqual(state+1, s1[0][1])
    
    def test_action3(self):                    # Action 3 = Test if theta 2 of finger 1 decreases by 1
        env = PianoHandEnv('C')
        env.reset()
        s0 = env.finger_currangle
        state = s0[0][1]
        s1, r, d, _, _ = env.step(3)
        s2 = env.finger_currangle
        self.assertEqual(s1, s2)
        self.assertEqual(state-1, s1[0][1])
     
    def test_action4(self):                    # Action 4 = Test if theta 1 of finger 2 increases by 1
        env = PianoHandEnv('C')
        env.reset()
        s0 = env.finger_currangle
        state = s0[1][0]
        s1, r, d, _, _ = env.step(4)
        s2 = env.finger_currangle
        self.assertEqual(s1, s2)
        self.assertEqual(state+1, s1[1][0])
        
    def test_action5(self):                    # Action 5 = Test if theta 1 of finger 2 decreases by 1
        env = PianoHandEnv('C')
        env.reset()
        s0 = env.finger_currangle
        state = s0[1][0]
        s1, r, d, _, _ = env.step(5)
        s2 = env.finger_currangle
        self.assertEqual(s1,s2)
        self.assertEqual(state-1, s1[1][0])
        
    def test_action6(self):                    # Action 6 = Test if theta 2 of finger 2 increases by 1
        env = PianoHandEnv('C')
        env.reset()
        s0 = env.finger_currangle
        state = s0[1][1]
        s1, r, d, _, _ = env.step(6)
        s2 = env.finger_currangle
        self.assertEqual(s1,s2)
        self.assertEqual(state+1, s1[1][1])
    
    def test_action7(self):                    # Action 7 = Test if theta 2 of finger 2 decreases by 1
        env = PianoHandEnv('C')
        env.reset()
        s0 = env.finger_currangle
        state = s0[1][1]
        s1, r, d, _, _ = env.step(7)
        s2 = env.finger_currangle
        self.assertEqual(s1,s2)
        self.assertEqual(state-1, s1[1][1])
      
    def test_action8(self):                    # Action 8 = Test if theta 1 of finger 3 increases by 1
        env = PianoHandEnv('C')
        env.reset()
        s0 = env.finger_currangle
        state = s0[2][0]
        s1, r, d, _, _ = env.step(8)
        s2 = env.finger_currangle
        self.assertEqual(s1,s2)
        self.assertEqual(state+1, s1[2][0])
        
    def test_action9(self):                    # Action 9 = Test if theta 1 of finger 3 decreases by 1
        env = PianoHandEnv('C')
        env.reset()
        s0 = env.finger_currangle
        state = s0[2][0]
        s1, r, d, _, _ = env.step(9)
        s2 = env.finger_currangle
        self.assertEqual(s1,s2)
        self.assertEqual(state-1, s1[2][0])
        
    def test_action10(self):                   # Action 10 = Test if theta 2 of finger 3 increases by 1
        env = PianoHandEnv('C')
        env.reset()
        s0 = env.finger_currangle
        state = s0[2][1]
        s1, r, d, _, _ = env.step(10)
        s2 = env.finger_currangle
        self.assertEqual(s1,s2)
        self.assertEqual(state+1, s1[2][1])
        
    def test_action11(self):                   # Action 11 = Test if theta 2 of finger 3 decreases by 1
        env = PianoHandEnv('C')
        env.reset()
        s0 = env.finger_currangle
        state = s0[2][1]
        s1, r, d, _, _ = env.step(11)
        s2 = env.finger_currangle
        self.assertEqual(s1,s2)
        self.assertEqual(state-1, s1[2][1])
        
    def test_action12(self):                   # Action 12 = Test if theta 1 of finger 4 increases by 1
        env = PianoHandEnv('C')
        env.reset()
        s0 = env.finger_currangle
        state = s0[3][0]
        s1, r, d, _, _ = env.step(12)
        s2 = env.finger_currangle
        self.assertEqual(s1,s2)
        self.assertEqual(state+1, s1[3][0])
        
    def test_action13(self):                   # Action 13 = Test if theta 1 of finger 4 decreases by 1
        env = PianoHandEnv('C')
        env.reset()
        s0 = env.finger_currangle
        state = s0[3][0]
        s1, r, d, _, _ = env.step(13)
        s2 = env.finger_currangle
        self.assertEqual(s1,s2)
        self.assertEqual(state-1, s1[3][0])
        
    def test_action14(self):                   # Action 14 = Test if theta 2 of finger 4 increases by 1
        env = PianoHandEnv('C')
        env.reset()
        s0 = env.finger_currangle
        state = s0[3][1]
        s1, r, d, _, _ = env.step(14)
        s2 = env.finger_currangle
        self.assertEqual(s1,s2)
        self.assertEqual(state+1, s1[3][1])
        
    def test_action15(self):                   # Action 15 = Test if theta 2 of finger 4 decreases by 1
        env = PianoHandEnv('C')
        env.reset()
        s0 = env.finger_currangle
        state = s0[3][1]
        s1, r, d, _, _ = env.step(15)
        s2 = env.finger_currangle
        self.assertEqual(s1,s2)
        self.assertEqual(state-1, s1[3][1])
      
    def test_reward_finger1(self):          # Test if done and reward are updated accordingly when correct goal is reached
        env = PianoHandEnv('C')
        env.reset()
        for i in range(10):
            s, r, d, _, _ = env.step(12)
        self.assertTrue(d)
        self.assertEqual(r, 200)
        
    def test_reward_finger2(self):          # Test if done and reward are updated accordingly when wrong goal is reached
        env = PianoHandEnv('D')
        env.reset()
        for i in range(10):
            s, r, d, _, _ = env.step(12)
        self.assertTrue(d)
        self.assertEqual(r, -25)
        
    def test_reward_out_of_range(self):     # Test if done and reward are updated accordingly when a finger goes out of range
        env = PianoHandEnv('C')
        env.reset()
        for i in range(17):
            s, r, d, _, _ = env.step(13)
        self.assertTrue(d)
        self.assertEqual(r, -10)        
        
unittest.main(argv=[''], verbosity=2, exit=False)
